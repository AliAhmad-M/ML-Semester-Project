# %% [markdown]
# ### Loading Datasets

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

print("Lahore Air Quality Index (AQI) Data from 2019 to 2023")
lahore_aqi_df = pd.read_csv("input/lahore_aqi_2019_to_2023.csv")
display(lahore_aqi_df.head())

print("\nPakistan Weather Data from 2000 to 2024")
pakistan_weather_df = pd.read_csv("input/pakistan_weather_2000_2024.csv")
display(pakistan_weather_df.head())

print("\nLahore Weather Data")
lahore_weather_df = pd.read_csv("input/lahore_weather_data.csv")
display(lahore_weather_df.head())
# Out:
# Lahore Air Quality Index (AQI) Data from 2019 to 2023
#        date  aqi_pm2.5  max_temp_f  avg_temp_f  min_temp_f  max_dew_point_f  \
# 0  01-06-19      222.0         115       101.0          88               64
# 1  02-06-19      170.0         115       100.3          86               64
# 2  03-06-19      223.0         109        96.5          84               66
# 3  04-06-19      153.0         106        92.1          81               72
# 4  05-06-19      157.0         111        94.8          82               68
#
#    avg_dew_point_f  min_dew_point_f  max_humidity_percent  \
# 0             56.2               39                    40
# 1             61.1               57                    45
# 2             61.4               57                    49
# 3             64.3               57                    52
# 4             60.5               52                    55
#
#    avg_humidity_percent  min_humidity_percent  max_wind_speed_mph  \
# 0                  24.6                    10                  18
# 1                  28.6                    16                   9
# 2                  33.1                    18                  41
# 3                  40.1                    29                  20
# 4                  34.1                    15                  15
#
#    avg_wind_speed_mph  min_wind_speed_mph  max_pressure_in  avg_pressure_in  \
# 0                 4.2                   0             28.8             28.8
# 1                 5.9                   0             28.9             28.8
# 2                10.3                   0             28.8             28.1
# 3                 9.8                   0             28.8             28.8
# 4                 8.3                   0             28.8             28.8
#
#    min_pressure_in
# 0             28.7
# 1             28.7
# 2              0.0
# 3             28.7
# 4             28.8
# Pakistan Weather Data from 2000 to 2024
#        date  year  month  day  dayofweek  is_weekend  season       city  \
# 0  1/1/2000  2000      1    1          5           1  Winter  Islamabad
# 1  1/2/2000  2000      1    2          6           1  Winter  Islamabad
# 2  1/3/2000  2000      1    3          0           0  Winter  Islamabad
# 3  1/4/2000  2000      1    4          1           0  Winter  Islamabad
# 4  1/5/2000  2000      1    5          2           0  Winter  Islamabad
#
#    region  latitude  longitude  elevation  tmin  tmax  tavg  prcp  wspd  \
# 0  Punjab   33.6844    73.0479        540   3.1  17.2   9.4   0.0   6.0
# 1  Punjab   33.6844    73.0479        540   2.9  17.4   9.3   0.0   6.1
# 2  Punjab   33.6844    73.0479        540   3.1  17.7   9.6   0.0   6.2
# 3  Punjab   33.6844    73.0479        540   3.4  17.6   9.6   0.0   5.9
# 4  Punjab   33.6844    73.0479        540   3.2  17.5   9.6   0.0   8.0
#
#    humidity  pressure  dew_point  cloud_cover  visibility  temp_range  \
# 0        76    1018.9        4.8            0         NaN        14.1
# 1        77    1018.6        4.8            0         NaN        14.5
# 2        76    1016.8        5.0            0         NaN        14.6
# 3        75    1016.2        4.8            0         NaN        14.2
# 4        77    1017.5        5.3            0         NaN        14.3
#
#    is_hot_day  is_cold_day rainfall_intensity wind_category
# 0           0            0               none         windy
# 1           0            0               none         windy
# 2           0            0               none         windy
# 3           0            0               none         windy
# 4           0            0               none         windy
# Lahore Weather Data
#        Date region  preciptation (mm)  temp_max (celcius)  temp_min (celcius)  \
# 0  1/1/1960    lhr                 20                18.1                 4.1
# 1  1/2/1960    lhr                  0                25.0                 9.9
# 2  1/3/1960    lhr                 31                25.6                12.3
# 3  1/4/1960    lhr                 11                31.9                17.0
# 4  1/5/1960    lhr                  3                39.0                23.4
#
#    soil_moisture (mm)
# 0                19.4
# 1                16.7
# 2                14.6
# 3                13.1
# 4                11.8

# %% [markdown]
# ### Checking Columns

# %%
print(f"Lahore AQI DataFrame Columns:")
for column in lahore_aqi_df.columns:
    print(column)

print(f"\nPakistan Weather DataFrame Columns:")
for column in pakistan_weather_df.columns:
    print(column)

print(f"\nLahore Weather DataFrame Columns:") 
for column in lahore_weather_df.columns:
    print(column)
# Out:
# Lahore AQI DataFrame Columns:
# date
# aqi_pm2.5
# max_temp_f
# avg_temp_f
# min_temp_f
# max_dew_point_f
# avg_dew_point_f
# min_dew_point_f
# max_humidity_percent
# avg_humidity_percent
# min_humidity_percent
# max_wind_speed_mph
# avg_wind_speed_mph
# min_wind_speed_mph
# max_pressure_in
# avg_pressure_in
# min_pressure_in
#
# Pakistan Weather DataFrame Columns:
# date
# year
# month
# day
# dayofweek
# is_weekend
# season
# city
# region
# latitude
# longitude
# elevation
# tmin
# tmax
# tavg
# prcp
# wspd
# humidity
# pressure
# dew_point
# cloud_cover
# visibility
# temp_range
# is_hot_day
# is_cold_day
# rainfall_intensity
# wind_category
#
# Lahore Weather DataFrame Columns:
# Date
# region
# preciptation (mm)
# temp_max (celcius)
# temp_min (celcius)
# soil_moisture (mm)

# %% [markdown]
# ### Filter Pakistan Weather Dataset to Lahore

# %%
pakistan_weather_df = pakistan_weather_df[
    pakistan_weather_df['city'].str.lower() == 'lahore'
]

display(pakistan_weather_df.head())
# Out:
#            date  year  month  day  dayofweek  is_weekend  season    city  \
# 14976  1/1/2016  2016      1    1          4           0  Winter  Lahore
# 14977  1/2/2016  2016      1    2          5           1  Winter  Lahore
# 14978  1/3/2016  2016      1    3          6           1  Winter  Lahore
# 14979  1/4/2016  2016      1    4          0           0  Winter  Lahore
# 14980  1/5/2016  2016      1    5          1           0  Winter  Lahore
#
#        region  latitude  longitude  elevation  tmin  tmax  tavg  prcp  wspd  \
# 14976  Punjab   31.5497    74.3436        217   9.9  20.9  14.5   0.0   6.6
# 14977  Punjab   31.5497    74.3436        217   6.2  20.6  13.1   0.0  10.8
# 14978  Punjab   31.5497    74.3436        217   7.6  21.6  14.2   0.0  10.4
# 14979  Punjab   31.5497    74.3436        217   9.5  20.9  14.7   0.6   7.8
# 14980  Punjab   31.5497    74.3436        217   8.9  21.9  14.9   0.0   9.6
#
#        humidity  pressure  dew_point  cloud_cover  visibility  temp_range  \
# 14976        64    1021.0        7.3           46         NaN        11.0
# 14977        69    1021.9        6.8           37         NaN        14.4
# 14978        65    1018.7        6.9           34         NaN        14.0
# 14979        73    1018.7        9.5           63         NaN        11.4
# 14980        77    1018.6       10.3           27         NaN        13.0
#
#        is_hot_day  is_cold_day rainfall_intensity wind_category
# 14976           0            0               none         windy
# 14977           0            0               none         windy
# 14978           0            0               none         windy
# 14979           0            0              light         windy
# 14980           0            0               none         windy

# %% [markdown]
# ### Checking Date Range

# %%
# Lahore AQI
lahore_aqi_df['date'] = pd.to_datetime(lahore_aqi_df['date'], format="%d-%m-%y")
print("Lahore AQI Date Range:",
      lahore_aqi_df['date'].min().strftime("%d-%m-%y"),
      "to",
      lahore_aqi_df['date'].max().strftime("%d-%m-%y"))

# Pakistan Weather
pakistan_weather_df['date'] = pd.to_datetime(pakistan_weather_df['date'], format="%m/%d/%Y")
print("Pakistan Weather Date Range:",
      pakistan_weather_df['date'].min().strftime("%d-%m-%y"),
      "to",
      pakistan_weather_df['date'].max().strftime("%d-%m-%y"))

# Lahore Weather
lahore_weather_df['Date'] = pd.to_datetime(lahore_weather_df['Date'], format="%m/%d/%Y")
print("Lahore Weather Date Range:",
      lahore_weather_df['Date'].min().strftime("%d-%m-%y"),
      "to",
      lahore_weather_df['Date'].max().strftime("%d-%m-%y"))
# Out:
# Lahore AQI Date Range: 01-06-19 to 30-11-23
# Pakistan Weather Date Range: 01-01-16 to 31-12-24
# Lahore Weather Date Range: 01-01-60 to 12-01-23

# %% [markdown]
# ### Standardize Date Columns

# %%
lahore_weather_df.rename(columns={'Date': 'date'}, inplace=True)

# %% [markdown]
# ### Check Overlapping Date Range

# %%
start_date = max(lahore_aqi_df['date'].min(),
                 pakistan_weather_df['date'].min())

end_date   = min(lahore_aqi_df['date'].max(),
                 pakistan_weather_df['date'].max())

print("Overlapping date range:", start_date.strftime("%d-%m-%y"), 
      "to", end_date.strftime("%d-%m-%y"))
# Out:
# Overlapping date range: 01-06-19 to 30-11-23

# %% [markdown]
# **Note:** We do not consider Lahore Weather Data, as it only contains data for first 2 days of each year

# %% [markdown]
# ### Keep Only Overlapping Date Range

# %%
lahore_aqi_df = lahore_aqi_df[(lahore_aqi_df['date'] >= start_date) & (lahore_aqi_df['date'] <= end_date)]
pakistan_weather_df = pakistan_weather_df[(pakistan_weather_df['date'] >= start_date) & (pakistan_weather_df['date'] <= end_date)]
lahore_weather_df = lahore_weather_df[(lahore_weather_df['date'] >= start_date) & (lahore_weather_df['date'] <= end_date)]

# %% [markdown]
# ### Standardize All Column Names

# %%
# Lahore AQI renaming
lahore_aqi_df = lahore_aqi_df.rename(columns={
    'max_temp_f': 'temp_max_c',
    'avg_temp_f': 'temp_avg_c',
    'min_temp_f': 'temp_min_c',
    'max_dew_point_f': 'dew_point_max_c',
    'avg_dew_point_f': 'dew_point_avg_c',
    'min_dew_point_f': 'dew_point_min_c',
    'max_humidity_percent': 'humidity_max_percent',
    'avg_humidity_percent': 'humidity_avg_percent',
    'min_humidity_percent': 'humidity_min_percent',
    'max_wind_speed_mph': 'wind_speed_max_mph',
    'avg_wind_speed_mph': 'wind_speed_avg_mph',
    'min_wind_speed_mph': 'wind_speed_min_mph',
    'max_pressure_in': 'pressure_max_in',
    'avg_pressure_in': 'pressure_avg_in',
    'min_pressure_in': 'pressure_min_in'
})

# Temperature columns in Lahore AQI that need conversion
temp_cols = ['temp_max_c', 'temp_avg_c', 'temp_min_c']
dew_cols  = ['dew_point_max_c', 'dew_point_avg_c', 'dew_point_min_c']

# Convert F -> C
for col in temp_cols + dew_cols:
    lahore_aqi_df[col] = (lahore_aqi_df[col] - 32) * 5 / 9

# Pakistan Weather renaming
pakistan_weather_df = pakistan_weather_df.rename(columns={
    'tmax': 'temp_max_c',
    'tmin': 'temp_min_c',
    'tavg': 'temp_avg_c',
    'dew_point': 'dew_point_c',
    'humidity': 'humidity_percent',
    'wspd': 'wind_speed_mph',
    'pressure': 'pressure_in',
    'prcp': 'precip_mm'
})

# Lahore Weather renaming
lahore_weather_df = lahore_weather_df.rename(columns={
    'temp_max (celcius)': 'temp_max_c',
    'temp_min (celcius)': 'temp_min_c',
    'preciptation (mm)': 'precip_mm',
    'soil_moisture (mm)': 'soil_moisture_mm'
})

# %% [markdown]
# ### Merge All 3 Dataframes

# %%
merged_df = (
    lahore_aqi_df
        .merge(pakistan_weather_df, on='date', how='left', suffixes=('', '_pak_weather'))
        .merge(lahore_weather_df, on='date', how='left', suffixes=('', '_lhr_weather'))
)

merged_df = merged_df.sort_values('date').reset_index(drop=True)
display(merged_df.head())
for column in merged_df.columns:
    print(column)
# Out:
#         date  aqi_pm2.5  temp_max_c  temp_avg_c  temp_min_c  dew_point_max_c  \
# 0 2019-06-01      222.0   46.111111   38.333333   31.111111        17.777778
# 1 2019-06-02      170.0   46.111111   37.944444   30.000000        17.777778
# 2 2019-06-03      223.0   42.777778   35.833333   28.888889        18.888889
# 3 2019-06-04      153.0   41.111111   33.388889   27.222222        22.222222
# 4 2019-06-05      157.0   43.888889   34.888889   27.777778        20.000000
#
#    dew_point_avg_c  dew_point_min_c  humidity_max_percent  \
# 0        13.444444         3.888889                    40
# 1        16.166667        13.888889                    45
# 2        16.333333        13.888889                    49
# 3        17.944444        13.888889                    52
# 4        15.833333        11.111111                    55
#
#    humidity_avg_percent  humidity_min_percent  wind_speed_max_mph  \
# 0                  24.6                    10                  18
# 1                  28.6                    16                   9
# 2                  33.1                    18                  41
# 3                  40.1                    29                  20
# 4                  34.1                    15                  15
#
#    wind_speed_avg_mph  wind_speed_min_mph  pressure_max_in  pressure_avg_in  \
# 0                 4.2                   0             28.8             28.8
# 1                 5.9                   0             28.9             28.8
# 2                10.3                   0             28.8             28.1
# 3                 9.8                   0             28.8             28.8
# 4                 8.3                   0             28.8             28.8
#
#    pressure_min_in  year  month  day  dayofweek  is_weekend  season    city  \
# 0             28.7  2019      6    1          5           1  Summer  Lahore
# 1             28.7  2019      6    2          6           1  Summer  Lahore
# 2              0.0  2019      6    3          0           0  Summer  Lahore
# 3             28.7  2019      6    4          1           0  Summer  Lahore
# 4             28.8  2019      6    5          2           0  Summer  Lahore
#
#    region  latitude  longitude  elevation  temp_min_c_pak_weather  \
# 0  Punjab   31.5497    74.3436        217                    26.7
# 1  Punjab   31.5497    74.3436        217                    27.4
# 2  Punjab   31.5497    74.3436        217                    28.3
# 3  Punjab   31.5497    74.3436        217                    29.2
# 4  Punjab   31.5497    74.3436        217                    27.7
#
#    temp_max_c_pak_weather  temp_avg_c_pak_weather  precip_mm  wind_speed_mph  \
# 0                    44.1                    36.4        0.0            11.3
# 1                    44.1                    36.1        0.0            20.5
# 2                    44.2                    35.9        0.0            33.3
# 3                    42.1                    34.4        0.3            21.9
# 4                    42.6                    35.4        0.0            19.7
#
#    humidity_percent  pressure_in  dew_point_c  cloud_cover  visibility  \
# 0                21        998.4          9.0           11         NaN
# 1                23        998.7         10.5            3         NaN
# 2                28        997.7         14.0            9         NaN
# 3                39        999.4         18.0           12         NaN
# 4                30        999.5         12.7           40         NaN
#
#    temp_range  is_hot_day  is_cold_day rainfall_intensity wind_category  \
# 0        17.4           1            0               none         windy
# 1        16.7           1            0               none         windy
# 2        15.9           1            0               none         windy
# 3        12.9           0            0              light         windy
# 4        14.9           1            0               none         windy
#
#   region_lhr_weather  precip_mm_lhr_weather  temp_max_c_lhr_weather  \
# 0                NaN                    NaN                     NaN
# 1                NaN                    NaN                     NaN
# 2                NaN                    NaN                     NaN
# 3                NaN                    NaN                     NaN
# 4                NaN                    NaN                     NaN
#
#    temp_min_c_lhr_weather  soil_moisture_mm
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# date
# aqi_pm2.5
# temp_max_c
# temp_avg_c
# temp_min_c
# dew_point_max_c
# dew_point_avg_c
# dew_point_min_c
# humidity_max_percent
# humidity_avg_percent
# humidity_min_percent
# wind_speed_max_mph
# wind_speed_avg_mph
# wind_speed_min_mph
# pressure_max_in
# pressure_avg_in
# pressure_min_in
# year
# month
# day
# dayofweek
# is_weekend
# season
# city
# region
# latitude
# longitude
# elevation
# temp_min_c_pak_weather
# temp_max_c_pak_weather
# temp_avg_c_pak_weather
# precip_mm
# wind_speed_mph
# humidity_percent
# pressure_in
# dew_point_c
# cloud_cover
# visibility
# temp_range
# is_hot_day
# is_cold_day
# rainfall_intensity
# wind_category
# region_lhr_weather
# precip_mm_lhr_weather
# temp_max_c_lhr_weather
# temp_min_c_lhr_weather
# soil_moisture_mm

# %% [markdown]
# ### Percentage of NULL Values Per Column

# %%
null_percent = (merged_df.isnull().sum() / len(merged_df)) * 100
null_percent = null_percent.sort_values(ascending=False)
print(null_percent)
# Out:
# visibility                100.000000
# temp_min_c_lhr_weather     97.080292
# precip_mm_lhr_weather      97.080292
# region_lhr_weather         97.080292
# soil_moisture_mm           97.080292
# temp_max_c_lhr_weather     97.080292
# aqi_pm2.5                  13.442822
# date                        0.000000
# humidity_max_percent        0.000000
# humidity_avg_percent        0.000000
# temp_max_c                  0.000000
# temp_avg_c                  0.000000
# temp_min_c                  0.000000
# dew_point_max_c             0.000000
# dew_point_avg_c             0.000000
# dew_point_min_c             0.000000
# pressure_avg_in             0.000000
# pressure_max_in             0.000000
# wind_speed_min_mph          0.000000
# wind_speed_avg_mph          0.000000
# wind_speed_max_mph          0.000000
# humidity_min_percent        0.000000
# pressure_min_in             0.000000
# year                        0.000000
# region                      0.000000
# latitude                    0.000000
# month                       0.000000
# day                         0.000000
# dayofweek                   0.000000
# is_weekend                  0.000000
# season                      0.000000
# city                        0.000000
# precip_mm                   0.000000
# temp_avg_c_pak_weather      0.000000
# temp_max_c_pak_weather      0.000000
# temp_min_c_pak_weather      0.000000
# elevation                   0.000000
# longitude                   0.000000
# pressure_in                 0.000000
# wind_speed_mph              0.000000
# is_hot_day                  0.000000
# temp_range                  0.000000
# cloud_cover                 0.000000
# dew_point_c                 0.000000
# humidity_percent            0.000000
# wind_category               0.000000
# is_cold_day                 0.000000
# rainfall_intensity          0.000000
# dtype: float64

# %% [markdown]
# ### Check Unique Values In Cagtegorical Columns

# %%
# Unique values
print("Unique values in wind_category:")
print(merged_df["wind_category"].unique())

print("\nUnique values in rainfall_intensity:")
print(merged_df["rainfall_intensity"].unique())

print("\nUnique values in season:")
print(merged_df["season"].unique())
# Out:
# Unique values in wind_category:
# ['windy']
#
# Unique values in rainfall_intensity:
# ['none' 'light' 'moderate' 'heavy']
#
# Unique values in season:
# ['Summer' 'Autumn' 'Winter' 'Spring']

# %% [markdown]
# ### Drop NULL and redundant columns

# %%
# Drop visibility as it has 100% null values
# Drop redundant columns also
merged_df = merged_df.drop(columns=[
    'city', 'region', 'latitude', 'longitude', 'elevation', 
    'visibility', 'wind_category', 'region_lhr_weather', 'soil_moisture_mm' 
])

for column in merged_df.columns:
    print(column)
# Out:
# date
# aqi_pm2.5
# temp_max_c
# temp_avg_c
# temp_min_c
# dew_point_max_c
# dew_point_avg_c
# dew_point_min_c
# humidity_max_percent
# humidity_avg_percent
# humidity_min_percent
# wind_speed_max_mph
# wind_speed_avg_mph
# wind_speed_min_mph
# pressure_max_in
# pressure_avg_in
# pressure_min_in
# year
# month
# day
# dayofweek
# is_weekend
# season
# temp_min_c_pak_weather
# temp_max_c_pak_weather
# temp_avg_c_pak_weather
# precip_mm
# wind_speed_mph
# humidity_percent
# pressure_in
# dew_point_c
# cloud_cover
# temp_range
# is_hot_day
# is_cold_day
# rainfall_intensity
# precip_mm_lhr_weather
# temp_max_c_lhr_weather
# temp_min_c_lhr_weather

# %% [markdown]
# - The columns - city, region, latitude, longitude, elevation remain same for Lahore
# - The columns - visibility, soil_moisture_mm is 100% null
# - The columns - is_hot_day, is_cold_day, wind_category, temp_range and rainfall_intensity can be determined by other features

# %% [markdown]
# **Note:** We shall handle the precip_mm_lhr_weather, temp_max_c_lhr_weather, temp_min_c_lhr_weather columns later

# %% [markdown]
# ### Remove Duplicate Columns

# %%
# Same columns coming from multiple sources
merged_df = merged_df.drop(columns=[
    'temp_max_c_pak_weather', 'temp_avg_c_pak_weather', 'temp_min_c_pak_weather', 
    'temp_max_c_lhr_weather', 'temp_min_c_lhr_weather', 'precip_mm_lhr_weather',
    'dew_point_c', 'pressure_in', 'humidity_percent', 'wind_speed_mph'

])

for column in merged_df.columns:
    print(column)

print(f"\nTotal Number of Rows: {merged_df.shape[0]}")
# Out:
# date
# aqi_pm2.5
# temp_max_c
# temp_avg_c
# temp_min_c
# dew_point_max_c
# dew_point_avg_c
# dew_point_min_c
# humidity_max_percent
# humidity_avg_percent
# humidity_min_percent
# wind_speed_max_mph
# wind_speed_avg_mph
# wind_speed_min_mph
# pressure_max_in
# pressure_avg_in
# pressure_min_in
# year
# month
# day
# dayofweek
# is_weekend
# season
# precip_mm
# cloud_cover
# temp_range
# is_hot_day
# is_cold_day
# rainfall_intensity
#
# Total Number of Rows: 1644

# %% [markdown]
# ### Impute NULL aqi_pm2.5

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Initialize imputer (default uses BayesianRidge)
imputer = IterativeImputer(max_iter=10, random_state=42)

# Fit and transform in-place (numeric columns only)
numeric_cols = merged_df.select_dtypes(include=['float64', 'int64', 'uint8']).columns
merged_df[numeric_cols] = imputer.fit_transform(merged_df[numeric_cols])

print("Null values after imputation:")
print(merged_df.isnull().sum())
# Out:
# Null values after imputation:
# date                    0
# aqi_pm2.5               0
# temp_max_c              0
# temp_avg_c              0
# temp_min_c              0
# dew_point_max_c         0
# dew_point_avg_c         0
# dew_point_min_c         0
# humidity_max_percent    0
# humidity_avg_percent    0
# humidity_min_percent    0
# wind_speed_max_mph      0
# wind_speed_avg_mph      0
# wind_speed_min_mph      0
# pressure_max_in         0
# pressure_avg_in         0
# pressure_min_in         0
# year                    0
# month                   0
# day                     0
# dayofweek               0
# is_weekend              0
# season                  0
# precip_mm               0
# cloud_cover             0
# temp_range              0
# is_hot_day              0
# is_cold_day             0
# rainfall_intensity      0
# dtype: int64

# %% [markdown]
# ### Handle Outliers in Numerical Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = merged_df.select_dtypes(include=['float64', 'int64']).columns.drop(
    ['aqi_pm2.5', 'year', 'month', 'day', 'dayofweek', 'is_weekend']
)

plt.figure(figsize=(8, 16))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(len(numerical_cols) // 3 + 1, 3, i)
    sns.boxplot(y=merged_df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Define realistic bounds
temp_min, temp_max = -5, 55             # ceclius
wind_min, wind_max = 0, 80              # mph
pressure_min, pressure_max = 24, 36     # inHg
dew_point_min, dew_point_max = -5, 40   # celcius

# Filter rows within temperature, wind, pressure, and dew point bounds
merged_df = merged_df[
    (merged_df['temp_min_c'] >= temp_min) & (merged_df['temp_max_c'] <= temp_max) &
    (merged_df['wind_speed_min_mph'] >= wind_min) & (merged_df['wind_speed_max_mph'] <= wind_max) &
    (merged_df['pressure_min_in'] >= pressure_min) & (merged_df['pressure_max_in'] <= pressure_max) &
    (merged_df['dew_point_min_c'] >= dew_point_min) & (merged_df['dew_point_max_c'] <= dew_point_max)
]

# Check min and max after filtering
print(merged_df[['temp_min_c','temp_max_c','wind_speed_min_mph','wind_speed_max_mph',
                 'pressure_min_in','pressure_max_in','dew_point_min_c','dew_point_avg_c','dew_point_max_c']].agg(['min','max']))

print(f"Total rows after filtering extreme values: {merged_df.shape[0]}")
# Out:
#      temp_min_c  temp_max_c  wind_speed_min_mph  wind_speed_max_mph  \
# min    2.222222    7.777778                 0.0                 0.0
# max   32.777778   46.111111                12.0                77.0
#
#      pressure_min_in  pressure_max_in  dew_point_min_c  dew_point_avg_c  \
# min             27.9             28.6        -5.000000         1.500000
# max             29.4             29.5        26.111111        27.277778
#
#      dew_point_max_c
# min         2.777778
# max        33.888889
# Total rows after filtering extreme values: 1465

# %% [markdown]
# ### Applying One-Hot Encoding to Categorical Columns

# %%
merged_df = pd.get_dummies(
    merged_df,
    columns=['season', 'rainfall_intensity'], prefix=['season', 'rain']
)

display(merged_df.head())
# Out:
#         date  aqi_pm2.5  temp_max_c  temp_avg_c  temp_min_c  dew_point_max_c  \
# 0 2019-06-01      222.0   46.111111   38.333333   31.111111        17.777778
# 1 2019-06-02      170.0   46.111111   37.944444   30.000000        17.777778
# 3 2019-06-04      153.0   41.111111   33.388889   27.222222        22.222222
# 4 2019-06-05      157.0   43.888889   34.888889   27.777778        20.000000
# 5 2019-06-06      129.0   42.222222   35.000000   27.777778        15.000000
#
#    dew_point_avg_c  dew_point_min_c  humidity_max_percent  \
# 0        13.444444         3.888889                  40.0
# 1        16.166667        13.888889                  45.0
# 3        17.944444        13.888889                  52.0
# 4        15.833333        11.111111                  55.0
# 5        11.666667         8.888889                  42.0
#
#    humidity_avg_percent  humidity_min_percent  wind_speed_max_mph  \
# 0                  24.6                  10.0                18.0
# 1                  28.6                  16.0                 9.0
# 3                  40.1                  29.0                20.0
# 4                  34.1                  15.0                15.0
# 5                  26.0                  15.0                16.0
#
#    wind_speed_avg_mph  wind_speed_min_mph  pressure_max_in  pressure_avg_in  \
# 0                 4.2                 0.0             28.8             28.8
# 1                 5.9                 0.0             28.9             28.8
# 3                 9.8                 0.0             28.8             28.8
# 4                 8.3                 0.0             28.8             28.8
# 5                10.1                 5.0             28.9             28.8
#
#    pressure_min_in    year  month  day  dayofweek  is_weekend  precip_mm  \
# 0             28.7  2019.0    6.0  1.0        5.0         1.0        0.0
# 1             28.7  2019.0    6.0  2.0        6.0         1.0        0.0
# 3             28.7  2019.0    6.0  4.0        1.0         0.0        0.3
# 4             28.8  2019.0    6.0  5.0        2.0         0.0        0.0
# 5             28.8  2019.0    6.0  6.0        3.0         0.0        0.0
#
#    cloud_cover  temp_range  is_hot_day  is_cold_day  season_Autumn  \
# 0         11.0        17.4         1.0          0.0          False
# 1          3.0        16.7         1.0          0.0          False
# 3         12.0        12.9         0.0          0.0          False
# 4         40.0        14.9         1.0          0.0          False
# 5          9.0        14.1         0.0          0.0          False
#
#    season_Spring  season_Summer  season_Winter  rain_heavy  rain_light  \
# 0          False           True          False       False       False
# 1          False           True          False       False       False
# 3          False           True          False       False        True
# 4          False           True          False       False       False
# 5          False           True          False       False       False
#
#    rain_moderate  rain_none
# 0          False       True
# 1          False       True
# 3          False      False
# 4          False       True
# 5          False       True

# %% [markdown]
# ### Correlation Matrix

# %%
# Compute correlation matrix
corr_matrix = merged_df.corr()

# Correlation with target
target_corr = corr_matrix['aqi_pm2.5'].sort_values(ascending=False)
print(target_corr)
# Out:
# aqi_pm2.5               1.000000
# pressure_avg_in         0.572587
# pressure_max_in         0.565950
# pressure_min_in         0.555073
# season_Winter           0.518077
# rain_none               0.341660
# temp_range              0.301407
# humidity_max_percent    0.223297
# humidity_avg_percent    0.162649
# month                   0.160932
# season_Autumn           0.135056
# day                     0.024012
# humidity_min_percent    0.012518
# date                   -0.001194
# cloud_cover            -0.002733
# dayofweek              -0.022916
# is_weekend             -0.032225
# year                   -0.036030
# is_hot_day             -0.052020
# rain_moderate          -0.162200
# rain_light             -0.173885
# rain_heavy             -0.199884
# season_Spring          -0.224333
# precip_mm              -0.251099
# wind_speed_min_mph     -0.312367
# season_Summer          -0.406674
# wind_speed_max_mph     -0.432504
# temp_max_c             -0.516773
# dew_point_min_c        -0.557132
# dew_point_avg_c        -0.574488
# dew_point_max_c        -0.575906
# temp_avg_c             -0.578592
# wind_speed_avg_mph     -0.609669
# temp_min_c             -0.612549
# is_cold_day                  NaN
# Name: aqi_pm2.5, dtype: float64

# %% [markdown]
# ### Remove Features With Weak Correlation

# %%
merged_df = merged_df.drop(columns=['day', 'cloud_cover', 'dayofweek', 'is_weekend', 'year', 'is_hot_day', 'is_cold_day'])
for column in merged_df.columns:
    print(column)
# Out:
# date
# aqi_pm2.5
# temp_max_c
# temp_avg_c
# temp_min_c
# dew_point_max_c
# dew_point_avg_c
# dew_point_min_c
# humidity_max_percent
# humidity_avg_percent
# humidity_min_percent
# wind_speed_max_mph
# wind_speed_avg_mph
# wind_speed_min_mph
# pressure_max_in
# pressure_avg_in
# pressure_min_in
# month
# precip_mm
# temp_range
# season_Autumn
# season_Spring
# season_Summer
# season_Winter
# rain_heavy
# rain_light
# rain_moderate
# rain_none

# %% [markdown]
# ### Save Preprocessed Data in 'output' Folder

# %%
merged_df.to_csv("output/data_merged_cleaned.csv", index=False)
